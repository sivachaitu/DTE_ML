# %%
import numpy as np
from sklearn import preprocessing, model_selection, neighbors, svm
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv(r'C:\Users\sivac\Desktop\ML\archive\breast-cancer-wisconsin.data')

# %%
df
# Out:
#           id  clump_thickness  unif_cell_size  unif_cell_shape  marg_adhesion  \
# 0    1000025                5               1                1              1
# 1    1002945                5               4                4              5
# 2    1015425                3               1                1              1
# 3    1016277                6               8                8              1
# 4    1017023                4               1                1              3
# ..       ...              ...             ...              ...            ...
# 694   776715                3               1                1              1
# 695   841769                2               1                1              1
# 696   888820                5              10               10              3
# 697   897471                4               8                6              4
# 698   897471                4               8                8              5
#
# ...

# %%
df.replace('?', -99999, inplace = True)
df.drop(['id'],1, inplace=True)  #if inplace = True is not used the changes are not being comitted hence affecting the outcome

# %%
df.head()
# Out:
#    clump_thickness  unif_cell_size  unif_cell_shape  marg_adhesion  \
# 0                5               1                1              1
# 1                5               4                4              5
# 2                3               1                1              1
# 3                6               8                8              1
# 4                4               1                1              3
#
#    single_epith_size bare_nuclei  bland_chrom  norm_nucleoli  mitoses  class
# 0                  2           1            3              1        1      2
# 1                  7          10            3              2        1      2
# 2                  2           2            3              1        1      2
# 3                  3           4            3              7        1      2
# 4                  2           1            3              1        1      2

# %%
X = np.array(df.drop(['class'],axis= 1))

# %%
y = np.array(df['class'])

# %%
print(np.shape(y))
print(np.shape(X))
# Out:
# (699,)
# (699, 9)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y,test_size=0.2)

# %%
clf = neighbors.KNeighborsClassifier (n_jobs = -1) #imply change clf = svm.svc() to use svm instead of knn
clf.fit(X_train, y_train)
with open('kneighbor.pickle','wb') as f : #pickling .......
    pickle.dump(clf,f)
    
pickle_in = open('kneighbor.pickle','rb') 
clf = pickle.load(pickle_in)              #pickling end........
accuracy = clf.score(X_test, y_test)
print(accuracy)
# Out:
# 0.9714285714285714

# %%
predict_data = np.array([[2,1,4,3,2,1,5,4,3],[6,7,4,3,2,5,5,4,3]])

# %%
print(clf.predict(predict_data))
# Out:
# [2 4]
